# %%
import pandas as pd

# %%
df = pd.read_csv('all_heroes_stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  id                          name            hero primary_attr  \
# 0           0   1        npc_dota_hero_antimage       Anti-Mage          agi
# 1           1   2             npc_dota_hero_axe             Axe          str
# 2           2   3            npc_dota_hero_bane            Bane          int
# 3           3   4     npc_dota_hero_bloodseeker     Bloodseeker          agi
# 4           4   5  npc_dota_hero_crystal_maiden  Crystal Maiden          int
#
#   attack_type                                              roles  \
# 0       Melee                       ['Carry', 'Escape', 'Nuker']
# 1       Melee  ['Initiator', 'Durable', 'Disabler', 'Jungler'...
# 2      Ranged        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3       Melee  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4      Ranged        ['Support', 'Disabler', 'Nuker', 'Jungler']
#
#                                                  img  \
# 0  /apps/dota2/images/dota_react/heroes/antimage....
# ...

# %%
df['hero']
# Out:
# 0           Anti-Mage
# 1                 Axe
# 2                Bane
# 3         Bloodseeker
# 4      Crystal Maiden
#             ...
# 117       Void Spirit
# 118          Snapfire
# 119              Mars
# 120       Dawnbreaker
# 121             Marci
# Name: hero, Length: 122, dtype: object

# %%
df_hero = [df['hero']]

# %%
print(type(df_hero))
# Out:
# <class 'list'>

# %%
df
# Out:
#      Unnamed: 0   id                          name            hero  \
# 0             0    1        npc_dota_hero_antimage       Anti-Mage
# 1             1    2             npc_dota_hero_axe             Axe
# 2             2    3            npc_dota_hero_bane            Bane
# 3             3    4     npc_dota_hero_bloodseeker     Bloodseeker
# 4             4    5  npc_dota_hero_crystal_maiden  Crystal Maiden
# ..          ...  ...                           ...             ...
# 117         117  126     npc_dota_hero_void_spirit     Void Spirit
# 118         118  128        npc_dota_hero_snapfire        Snapfire
# 119         119  129            npc_dota_hero_mars            Mars
# 120         120  135     npc_dota_hero_dawnbreaker     Dawnbreaker
# 121         121  136           npc_dota_hero_marci           Marci
#
#     primary_attr attack_type  \
# 0            agi       Melee
# 1            str       Melee
# 2            int      Ranged
# 3            agi       Melee
# ...

# %%
test = pd.read_csv('overall_hero_cluster.csv')

# %%
test
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role
# ...

# %%
df = test

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df['x'] = df.groupby("gold_per_min")

# %%
df2 = test

# %%
df2['x'] = df2.groupby("hero_role")["gold_per_min"].mean()

# %%
test
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role  \
# ...

# %%
new_test = pd.read_csv('overall_hero_cluster.csv')

# %%
new_test
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role
# ...

# %%
value = new_test["gold_per_min"].mean()

# %%
value
# Out:
# 404.04269857567334

# %%
value = new_test.groupby("hero_role").mean()

# %%
value
# Out:
#                       gold_per_min    deaths    assists     kills  xp_per_min  \
# hero_role
# Hard-Carry              510.035467  7.104091   8.908441  8.121267  531.661507
# Offlaner/All-rounder    445.732863  7.453874  10.917144  8.231253  486.130424
# Soft-carry              344.066842  8.251750  13.099722  5.813362  383.348537
# Support                 402.646774  7.506062  11.523292  7.329004  441.590663
#
#                        last_hits  tower_damage  kmeans
# hero_role
# Hard-Carry            211.857188   3016.425722       3
# Offlaner/All-rounder  164.448628   1927.335100       2
# Soft-carry             75.104208    419.012044       0
# Support               125.562222   1136.840760       1

# %%
value3 = new_test['gold_per_min'].mean()

# %%
value3
# Out:
# 404.04269857567334

# %%
value['gold_per_min_average'] = new_test['gold_per_min']

# %%
value
# Out:
#                       gold_per_min    deaths    assists     kills  xp_per_min  \
# hero_role
# Hard-Carry              510.035467  7.104091   8.908441  8.121267  531.661507
# Offlaner/All-rounder    445.732863  7.453874  10.917144  8.231253  486.130424
# Soft-carry              344.066842  8.251750  13.099722  5.813362  383.348537
# Support                 402.646774  7.506062  11.523292  7.329004  441.590663
#
#                        last_hits  tower_damage  kmeans  gold_per_min_average
# hero_role
# Hard-Carry            211.857188   3016.425722       3                   NaN
# Offlaner/All-rounder  164.448628   1927.335100       2                   NaN
# Soft-carry             75.104208    419.012044       0                   NaN
# Support               125.562222   1136.840760       1                   NaN

# %%
new_test = pd.read_csv('overall_hero_cluster.csv')

# %%
new_test
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role
# ...

# %%
new_test['average_gold_per_min'] = new_test['gold_per_min'].mean()

# %%
new_test
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role  \
# ...

# %%
hero_role2 = new_test.groupby('kmeans')['gold_per_min']

# %%
hero_role2['average_gold_per_min_xxx'] = hero_role2['gold_per_min'].values.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-8f929e6ffd90> in <module>
# ----> 1 hero_role2['average_gold_per_min_xxx'] = hero_role2['gold_per_min'].values.mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'values'

# %%
hero_role2.tail()
# Out:
# 76     551.266302
# 78     347.610465
# 85     435.304113
# 86     470.050725
# 88     523.577292
# 89     488.280464
# 93     473.306692
# 95     464.797836
# 98     474.532078
# 99     315.887220
# 100    358.726700
# 101    435.457453
# 102    348.756269
# 103    342.182255
# 104    448.519486
# 105    434.759973
# 106    309.383266
# 107    311.429450
# 108    479.170003
# 109    406.194814
# Name: gold_per_min, dtype: float64

# %%
x = pd.read_csv('overall_hero_cluster.csv')

# %%
x.head()
# Out:
#                  hero  gold_per_min    deaths    assists     kills  \
# 0             Abaddon    363.055287  6.278550  12.647432  5.005740
# 1           Alchemist    709.545455  7.173369  11.647562  6.679019
# 2  Ancient Apparition    313.147046  7.492818  13.356286  4.826151
# 3           Anti-Mage    554.192742  5.449979   6.722222  7.340996
# 4                 Axe    400.109107  9.365138  10.498153  8.525321
#
#    xp_per_min   last_hits  tower_damage  kmeans   hero_role
# 0  417.260725   84.188822   1009.606949       1     Support
# 1  577.001832  265.160847   2585.172758       3  Hard-Carry
# 2  324.378054   48.930994    298.453280       0  Soft-carry
# 3  580.392827  298.673585   3081.401767       3  Hard-Carry
# 4  442.938274  136.269724    453.616605       0  Soft-carry

# %%
x2 = x

# %%
x2
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role
# ...

# %%
x2 = x.groupby('hero_role')['gold_per_min'].mean()

# %%
x2 = pd.DataFrame(x2)

# %%
x2
# Out:
#                       gold_per_min
# hero_role
# Hard-Carry              510.035467
# Offlaner/All-rounder    445.732863
# Soft-carry              344.066842
# Support                 402.646774

# %%
# Out:
#                     0
# 0           hero_role
# 1        gold_per_min
# 2  class_gold_per_min

# %%
x2 = x2.reset_index('hero_role')

# %%
x2
# Out:
#               hero_role  gold_per_min
# 0            Hard-Carry    510.035467
# 1  Offlaner/All-rounder    445.732863
# 2            Soft-carry    344.066842
# 3               Support    402.646774

# %%
# Out:
# <class 'method'>

# %%
x
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role
# ...

# %%
x3 = x

# %%
x3['average_gold_per_min'] = x3['gold_per_min'].mean()

# %%
x3
# Out:
#                    hero  gold_per_min    deaths    assists      kills  \
# 0               Abaddon    363.055287  6.278550  12.647432   5.005740
# 1             Alchemist    709.545455  7.173369  11.647562   6.679019
# 2    Ancient Apparition    313.147046  7.492818  13.356286   4.826151
# 3             Anti-Mage    554.192742  5.449979   6.722222   7.340996
# 4                   Axe    400.109107  9.365138  10.498153   8.525321
# ..                  ...           ...       ...        ...        ...
# 105          Windranger    434.759973  6.874000   9.979407   9.061491
# 106       Winter Wyvern    309.383266  7.674678  12.228401   3.637911
# 107        Witch Doctor    311.429450  8.706734  13.071985   5.791968
# 108         Wraith King    479.170003  5.665897  11.854632   7.865538
# 109                Zeus    406.194814  7.576814  18.238178  10.025278
#
#      xp_per_min   last_hits  tower_damage  kmeans             hero_role  \
# ...
