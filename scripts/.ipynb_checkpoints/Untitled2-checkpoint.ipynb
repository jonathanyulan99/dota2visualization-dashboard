# %%
import pandas as pd

# %%
df_1 = pd.read_csv('Anti-Mage_metric.csv')
df_3 = pd.read_csv('Bane_metric.csv')
df_2 = pd.read_csv('Axe_metric.csv')

# %%
dt_1 = pd.read_table('Anti-Mage_metric.csv')
dt_3 = pd.read_table('Bane_metric.csv')
dt_2 = pd.read_table('Axe_metric.csv')

# %%
#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'],
                                            #how='outer'), data_frames).fillna('void')

# %%
dt_total = [df_1, df_2, df_3]
df_total = pd.concat(dt_total, join='outer').fillna(0)
df_total.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0        1                               0.1
# 0           0        2                               0.1
# 0           0        3                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          427                               0.2
# 0                          328                               0.2
# 0                          204                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          504                               0.3
# 0                          365                               0.3
# 0                          228                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          573                               0.4
# 0                          400                               0.4
# ...

# %%
df_marci = pd.read_csv('Marci_metric.csv')

# %%
df_marci.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0      122                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          NaN                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          NaN                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          NaN                               0.4
#
#    result_gold_per_min_3_value  ...  result_lhten_6_percentile  \
# 0                          NaN  ...                        0.7
#
#    result_lhten_6_value  result_lhten_7_percentile  result_lhten_7_value  \
# 0                   NaN                        0.8                   NaN
#
#    result_lhten_8_percentile  result_lhten_8_value  result_lhten_9_percentile  \
# 0                        0.9                   NaN                       0.95
#
# ...

# %%
df_am = pd.read_csv('Anti-Mage_metric.csv')

# %%
df_am.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0        4                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          340                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          391                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          438                               0.4
#
#    result_gold_per_min_3_value  ...  result_lhten_6_percentile  \
# 0                          467  ...                        0.7
#
#    result_lhten_6_value  result_lhten_7_percentile  result_lhten_7_value  \
# 0                    49                        0.8                    55
#
#    result_lhten_8_percentile  result_lhten_8_value  result_lhten_9_percentile  \
# 0                        0.9                    61                       0.95
#
# ...

# %%
df_axe = pd.read_csv('Axe_metric.csv')

# %%
df_axe.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0        5                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          227                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          248                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          272                               0.4
#
#    result_gold_per_min_3_value  ...  result_lhten_6_percentile  \
# 0                          290  ...                        0.7
#
#    result_lhten_6_value  result_lhten_7_percentile  result_lhten_7_value  \
# 0                     8                        0.8                    10
#
#    result_lhten_8_percentile  result_lhten_8_value  result_lhten_9_percentile  \
# 0                        0.9                    13                       0.95
#
# ...

# %%
df_am.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0     2000                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          NaN                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          NaN                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          NaN                               0.4
#
#    result_gold_per_min_3_value  ...  result_lhten_6_percentile  \
# 0                          NaN  ...                        0.7
#
#    result_lhten_6_value  result_lhten_7_percentile  result_lhten_7_value  \
# 0                   NaN                        0.8                   NaN
#
#    result_lhten_8_percentile  result_lhten_8_value  result_lhten_9_percentile  \
# 0                        0.9                   NaN                       0.95
#
# ...

# %%
df_3.head()
# Out:
#    Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0           0        3                               0.1
#
#    result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                          204                               0.2
#
#    result_gold_per_min_1_value  result_gold_per_min_2_percentile  \
# 0                          228                               0.3
#
#    result_gold_per_min_2_value  result_gold_per_min_3_percentile  \
# 0                          250                               0.4
#
#    result_gold_per_min_3_value  ...  result_lhten_6_percentile  \
# 0                          268  ...                        0.7
#
#    result_lhten_6_value  result_lhten_7_percentile  result_lhten_7_value  \
# 0                     7                        0.8                     8
#
#    result_lhten_8_percentile  result_lhten_8_value  result_lhten_9_percentile  \
# 0                        0.9                    10                       0.95
#
# ...

# %%
df = pd.DataFrame(columns=['Name','Age','Sex'])
df.loc[0] = ["Jonathan",21,"Male"]

# %%
df.head(1)
# Out:
#        Name Age   Sex
# 0  Jonathan  21  Male

# %%
data1= {
    'Name':['Jonathan'],
    'Age':['21'],
    'Sex':['Male']
}

df1 = pd.DataFrame(data1)
df1
# Out:
#        Name Age   Sex
# 0  Jonathan  21  Male

# %%
data2= {
    'Name':['Caitlin'],
    'Age':['17'],
    'Sex':['Female']
}

df2 = pd.DataFrame.from_dict(data2)
df2
# Out:
#       Name Age     Sex
# 0  Caitlin  17  Female

# %%
data3= {
    'Name':["Fanzzy"],
    'Age':["29"],
    'Sex':["M"],
    'Sign':["Scorpio"]
}

df3 = pd.DataFrame.from_dict(data3,orient='columns')
df3.head()
# Out:
#      Name Age Sex     Sign
# 0  Fanzzy  29   M  Scorpio

# %%
data3= {
    'Name':["Fanzzy"],
    'Age':["29"],
    'Sex':["M"],
    'Sign':["Scorpio"]
}

df3 = pd.DataFrame.from_dict(data3,orient='index',columns=['jonathan_yulan'])
df3.head()
# Out:
#      jonathan_yulan
# Name         Fanzzy
# Age              29
# Sex               M
# Sign        Scorpio

# %%
overall_heroes_df = pd.read_csv('total_heroes_metrics.csv')

# %%
overall_heroes_df.columns.isnull().sum()

# %%
overall_heroes_df.index.isnull().sum()
# Out:
# 0

# %%
overall_heroes_df.iloc[0:len(overall_heroes_df)]
# Out:
#      Unnamed: 0  hero_id  result_gold_per_min_0_percentile  \
# 0             0        1                               0.1
# 1             1        2                               0.1
# 2             2        3                               0.1
# 3             3        4                               0.1
# 4             4        5                               0.1
# ..          ...      ...                               ...
# 117         117      126                               0.1
# 118         118      128                               0.1
# 119         119      129                               0.1
# 120         120      135                               0.1
# 121         121      136                               0.1
#
#      result_gold_per_min_0_value  result_gold_per_min_1_percentile  \
# 0                            427                               0.2
# 1                            328                               0.2
# ...

# %%
overall_heroes_metrics = pd.read_csv('')
